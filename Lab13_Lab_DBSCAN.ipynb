# %% [markdown]
# <a href="https://colab.research.google.com/github/chjohnso-um/chjohnso-um-CSC-587/blob/main/Lab13_Lab_DBSCAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_moons
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Generate a 2D dataset with non-convex clusters

# %%
X, y = make_moons(n_samples=300, noise=0.05, random_state=42)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Visualize
plt.scatter(X_scaled[:, 0], X_scaled[:, 1])
plt.title("Dataset for DBSCAN")
plt.show()

# %% [markdown]
# #Applying DBSCAN

# %%
dbscan = DBSCAN(eps=0.3, min_samples=5)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()

# %% [markdown]
# #Can you change epsilon and min values to observe how things change? For instance,
#
# * Try eps=0.1, eps=0.5 and observe the difference.
# * What happens when you change min_samples to 3 or 10?
# * Can you also identify noise for each trial. (Hint: np.sum(labels == -1) after you your clusters)

# %%
dbscan = DBSCAN(eps=0.1, min_samples=3)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()
np.sum(labels == -1)
# Out:
# np.int64(54)

# %%
dbscan = DBSCAN(eps=0.5, min_samples=10)
labels = dbscan.fit_predict(X_scaled)

# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=labels, cmap='plasma')
plt.title("DBSCAN Clustering")
plt.show()
np.sum(labels == -1)
# Out:
# np.int64(0)

# %% [markdown]
# #Use a real dataset:
# * Try load_iris() from sklearn.datasets.
# * Apply DBSCAN

# %%
from sklearn.datasets import load_iris
iris = load_iris()
#X, y = load_iris(return_X_y=True)

# Standardize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(iris.data)

# Do the DBSCAN
#dbscan = DBSCAN(eps=1, min_samples=10)
dbscan = DBSCAN(eps=1, min_samples=5)
dbscan.fit(X_scaled)

# Visualize
# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=dbscan.labels_, cmap='plasma')
plt.title("Iris Dataset for DBSCAN")
plt.show()

# %%
# Do the DBSCAN
# Trying different epsilon and min_samples
dbscan = DBSCAN(eps=0.5, min_samples=10)
dbscan.fit(X_scaled)

# Visualize
# Plot clusters
plt.scatter(X_scaled[:, 0], X_scaled[:, 1], c=dbscan.labels_, cmap='plasma')
plt.title("Iris Dataset for DBSCAN")
plt.show()
